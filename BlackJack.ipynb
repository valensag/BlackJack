# %%
import import_ipynb
import General_Program
general = General_Program.General
class Run_BlackJack():
    def __init__(self,total_amount = 0, total_cantidad = 0):
        self.total_amount = total_amount
        self.total_cantidad = total_cantidad
        
        general.__init__(self)
        general.instructions(self)
        general.start_game(self)
        general.show_bet_image(self)
        general.start_player_turn(self)
        general.start_dealer_turn(self)
        general.select_winner(self)
        general.amount(self)
# Out:
# importing Jupyter notebook from General_Program.ipynb
# importing Jupyter notebook from module_dealer.ipynb
# importing Jupyter notebook from module_player.ipynb

# %%
Play = Run_BlackJack()
# Out:
# **DEALER TURN**
# DEALER LOSE! exceeded 21!
# **YOU WIN!** Congratulations! 😊
# SCORE:  22
# Total amount Player:  1100
# Total amount Dealer:  900
